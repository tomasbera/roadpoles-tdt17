# %%
from ultralytics import YOLO
import cv2

# %%
model = YOLO("../runs_11n/detect/train/weights/best.pt")
results = model.predict(source="../dataset/roadpoles_preprocessed/valid/images/frame_001265.PNG")
plot = results[0].plot()
# Out:
# image 1/1 C:\Users\tomas\PycharmProjects\roadpoles-tdt17\yolo\..\dataset\roadpoles_preprocessed\valid\images\frame_001265.PNG: 416x1280 2 poles, 56.1ms
# Speed: 3.7ms preprocess, 56.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 1280)

# %%
cv2.imshow("Snow Pole Detection", plot)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
model = YOLO("../yolo/runs/detect/train3/weights/best.pt")
results = model.predict(source="../dataset/roadpoles_v1/valid/images/frame_001265.PNG")
plot = results[0].plot()
cv2.imshow("Snow Pole Detection", plot)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# image 1/1 C:\Users\tomas\PycharmProjects\roadpoles-tdt17\yolo\..\dataset\roadpoles_v1\valid\images\frame_001265.PNG: 416x640 (no detections), 46.7ms
# Speed: 2.5ms preprocess, 46.7ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 640)

# %%
print()
